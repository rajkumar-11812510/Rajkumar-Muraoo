# %% [markdown]
# <a href="https://colab.research.google.com/github/rajkumar-11812510/Rajkumar-Muraoo/blob/main/PythonDataframe2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from numpy.random import randn
np.random.seed(101)

# %%
# integer=5,4, index=A,B,C,D,E, Column=W,X,Y,Z
df=pd.DataFrame(randn(5,4), ['A','B','C','D','E'],['W','X','Y','Z'])
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df['W']
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Printing multiplecolumn
df[['X','Z']]
# Out:
#           X         Z
# A  0.628133  0.503826
# B -0.319318  0.605965
# C  0.740122 -0.589001
# D -0.758872  0.955057
# E  1.978757  0.683509

# %%
# Adding new column
df['new']=df['W']+df['X']
df
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.334983
# B  0.651118 -0.319318 -0.848077  0.605965  0.331800
# C -2.018168  0.740122  0.528813 -0.589001 -1.278046
# D  0.188695 -0.758872 -0.933237  0.955057 -0.570177
# E  0.190794  1.978757  2.605967  0.683509  2.169552

# %%
df.drop('new',axis=1)
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.drop('E')
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.334983
# B  0.651118 -0.319318 -0.848077  0.605965  0.331800
# C -2.018168  0.740122  0.528813 -0.589001 -1.278046
# D  0.188695 -0.758872 -0.933237  0.955057 -0.570177

# %%
# 2 Ways for selecting rows
df.loc['A'] # Label based Location
# Out:
# W      2.706850
# X      0.628133
# Y      0.907969
# Z      0.503826
# new    3.334983
# Name: A, dtype: float64

# %%
df.iloc[0]
# Integer Based Location
# Out:
# W      2.706850
# X      0.628133
# Y      0.907969
# Z      0.503826
# new    3.334983
# Name: A, dtype: float64

# %%
# Subsets of DataFrame
df.loc[['A','B'],['Z','X']]
# Out:
#           Z         X
# A  0.503826  0.628133
# B  0.605965 -0.319318

# %% [markdown]
# # Conditional Selection for data Frames using bracked notaion very similar to numpy

# %%
df>0
# Out:
#        W      X      Y      Z    new
# A   True   True   True   True   True
# B   True  False  False   True   True
# C  False   True   True  False  False
# D   True  False  False   True  False
# E   True   True   True   True   True

# %%
booldf=df>0
df[booldf]
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.334983
# B  0.651118       NaN       NaN  0.605965  0.331800
# C       NaN  0.740122  0.528813       NaN       NaN
# D  0.188695       NaN       NaN  0.955057       NaN
# E  0.190794  1.978757  2.605967  0.683509  2.169552

# %%
df[df>0]
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.334983
# B  0.651118       NaN       NaN  0.605965  0.331800
# C       NaN  0.740122  0.528813       NaN       NaN
# D  0.188695       NaN       NaN  0.955057       NaN
# E  0.190794  1.978757  2.605967  0.683509  2.169552

# %%
resultdf=df[df['Z']>0]
resultdf['Z']
# Out:
# A    0.503826
# B    0.605965
# D    0.955057
# E    0.683509
# Name: Z, dtype: float64

# %%
df[df['Z']<0]
# Out:
#           W         X         Y         Z       new
# C -2.018168  0.740122  0.528813 -0.589001 -1.278046

# %%
df
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.334983
# B  0.651118 -0.319318 -0.848077  0.605965  0.331800
# C -2.018168  0.740122  0.528813 -0.589001 -1.278046
# D  0.188695 -0.758872 -0.933237  0.955057 -0.570177
# E  0.190794  1.978757  2.605967  0.683509  2.169552

# %%
df[(df['Y']>0) & (df['Z']>1)]
# Out:
# Empty DataFrame
# Columns: [W, X, Y, Z, new]
# Index: []

# %%
df[(df['Y']>0) | (df['Z']>1)]     # | = ampersand or pipeline
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.334983
# C -2.018168  0.740122  0.528813 -0.589001 -1.278046
# E  0.190794  1.978757  2.605967  0.683509  2.169552

# %%
print(df[(df['Y'] > 0) | (df['Z'] > 1)])
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.334983
# C -2.018168  0.740122  0.528813 -0.589001 -1.278046
# E  0.190794  1.978757  2.605967  0.683509  2.169552

# %%
df.reset_index()
# Out:
#   index         W         X         Y         Z       new
# 0     A  2.706850  0.628133  0.907969  0.503826  3.334983
# 1     B  0.651118 -0.319318 -0.848077  0.605965  0.331800
# 2     C -2.018168  0.740122  0.528813 -0.589001 -1.278046
# 3     D  0.188695 -0.758872 -0.933237  0.955057 -0.570177
# 4     E  0.190794  1.978757  2.605967  0.683509  2.169552

# %% [markdown]
# Filtering Rows Based on Column Values

# %%
#  to filter rows where column W is greater than zero:
bool_series = df['W'] > 0
df[boolean_series]
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.334983
# B  0.651118 -0.319318 -0.848077  0.605965  0.331800
# D  0.188695 -0.758872 -0.933237  0.955057 -0.570177
# E  0.190794  1.978757  2.605967  0.683509  2.169552

# %%
newind='AB CD EF GH IJ'.split()
newind
# Out:
# ['AB', 'CD', 'EF', 'GH', 'IJ']

# %%
df['States']=newind
df
# Out:
#           W         X         Y         Z       new States
# A  2.706850  0.628133  0.907969  0.503826  3.334983     AB
# B  0.651118 -0.319318 -0.848077  0.605965  0.331800     CD
# C -2.018168  0.740122  0.528813 -0.589001 -1.278046     EF
# D  0.188695 -0.758872 -0.933237  0.955057 -0.570177     GH
# E  0.190794  1.978757  2.605967  0.683509  2.169552     IJ

# %%
df.set_index('States')
# Out:
#                W         X         Y         Z       new
# States
# AB      2.706850  0.628133  0.907969  0.503826  3.334983
# CD      0.651118 -0.319318 -0.848077  0.605965  0.331800
# EF     -2.018168  0.740122  0.528813 -0.589001 -1.278046
# GH      0.188695 -0.758872 -0.933237  0.955057 -0.570177
# IJ      0.190794  1.978757  2.605967  0.683509  2.169552
