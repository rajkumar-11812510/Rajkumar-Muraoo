# %% [markdown]
# <a href="https://colab.research.google.com/github/rajkumar-11812510/Rajkumar-Muraoo/blob/main/PythonDataframe1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from numpy.random import randn
np.random.seed(101)

# %%
# integer=5,4, index=A,B,C,D,E, Column=W,X,Y,Z
df=pd.DataFrame(randn(5,4), ['A','B','C','D','E'],['W','X','Y','Z'])
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478

# %%
df['W']
# Out:
# A   -0.993263
# B    1.025984
# C    2.154846
# D    0.147027
# E   -0.925874
# Name: W, dtype: float64

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Printing multiplecolumn
df[['X','Z']]
# Out:
#           X         Z
# A  0.196800  0.000366
# B -0.156598  0.649826
# C -0.610259 -0.346419
# D -0.479448  1.024810
# E  1.862864  0.610478

# %%
# Adding new column
df['new']=df['W']+df['X']
df
# Out:
#           W         X         Y         Z       new
# A -0.993263  0.196800 -1.136645  0.000366 -0.796464
# B  1.025984 -0.156598 -0.031579  0.649826  0.869386
# C  2.154846 -0.610259 -0.755325 -0.346419  1.544588
# D  0.147027 -0.479448  0.558769  1.024810 -0.332421
# E -0.925874  1.862864 -1.133817  0.610478  0.936990

# %%
df.drop('new',axis=1)
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478

# %%
df.drop('E')
# Out:
#           W         X         Y         Z       new
# A -0.993263  0.196800 -1.136645  0.000366 -0.796464
# B  1.025984 -0.156598 -0.031579  0.649826  0.869386
# C  2.154846 -0.610259 -0.755325 -0.346419  1.544588
# D  0.147027 -0.479448  0.558769  1.024810 -0.332421

# %%
# 2 Ways for selecting rows
df.loc['A']
# Out:
# W     -0.993263
# X      0.196800
# Y     -1.136645
# Z      0.000366
# new   -0.796464
# Name: A, dtype: float64

# %%
df.iloc[0]
# Out:
# W     -0.993263
# X      0.196800
# Y     -1.136645
# Z      0.000366
# new   -0.796464
# Name: A, dtype: float64

# %%
# Subsets of DataFrame
df.loc[['A','B'],['Z','X']]
# Out:
#           Z         X
# A  0.000366  0.196800
# B  0.649826 -0.156598
